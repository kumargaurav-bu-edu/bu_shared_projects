# %% [markdown]
# # 07 - Executive Summary & Business Framing
#
# **Milestone 1 — Part 1**: Frame the problem and look at the big picture.
#
# ## Purpose
# This notebook is completed **last** (after doing all EDA and cleaning) but addresses the **first** part of the milestone. After working through the data, you now have the context to answer the business-framing questions thoughtfully.
#
# ## Objectives
# - Answer the 3 business-framing questions (Part 1)
# - Summarize key findings from all prior notebooks
# - Outline next steps for Milestone 2
#
# ## Expected Outcomes
# | Deliverable | Description |
# |---|---|
# | Business objective (1.1) | Why does this project matter to Zillow? |
# | Solution usage (1.2) | How will the model be deployed/used? |
# | Success metrics (1.3) | How to measure model success or failure? |
# | Findings summary | Key takeaways from notebooks 01–06 |
# | Milestone 2 roadmap | What comes next |
#
# ---

# %% [markdown]
# ## Part 1: Frame the Problem
#
# Pretend you are working at Zillow as a data analyst. You have been given this dataset and asked to:
# 1. Analyze and understand the data
# 2. Create a regression model
# 3. Give a presentation to the marketing team about your results
#
# ---
#
# ### 1.1 — What is the objective of this project in business terms?
#
# *YOUR ANSWER HERE*
#
# Hints to consider:
# - What problem does an accurate property valuation solve for Zillow?
# - How does the Zestimate drive user engagement and revenue?
# - What is the cost of over- or under-estimating?
#
# ---
#
# ### 1.2 — How will your solution be used?
#
# *YOUR ANSWER HERE*
#
# Hints to consider:
# - Will it power a user-facing feature (like the Zestimate)?
# - Will it feed into downstream analytics or pricing dashboards?
# - Who are the consumers of this model's output?
#
# ---
#
# ### 1.3 — How should success (or failure) be measured?
#
# *YOUR ANSWER HERE*
#
# Hints to consider:
# - Regression metrics: RMSE, MAE, R², MAPE
# - Business metrics: % of predictions within X% of actual value
# - What threshold would be acceptable for a "good" model?

# %% [markdown]
# ---
# ## Summary of Key Findings (Notebooks 01–06)
#
# ### Data Quality (Notebook 01)
# - Dataset shape: ___ rows × ___ columns
# - Features with >80% missing: ___
# - Key categorical features: ___
#
# ### Distributions & Outliers (Notebook 02)
# - Target (`taxvaluedollarcnt`): ___ distribution, range $___–$___
# - Notable outliers in: ___
# - Most features are: ___ skewed
#
# ### Data Cleaning (Notebook 03)
# - Features dropped (business logic): ___
# - Features dropped (high nulls): ___
# - Samples removed: ___ (null target, outliers, high-null rows)
# - Imputation strategy: ___
# - Final clean shape: ___ rows × ___ columns
#
# ### Feature Relationships (Notebook 04)
# - Top correlated features with target: ___
# - Top F-score features: ___
# - Forward/backward SFS agreement: ___
#
# ### Bivariate Patterns (Notebook 05)
# - Key relationships observed: ___
#
# ### Feature Engineering (Notebook 06)
# - Most promising transformations: ___
# - Transformations to carry forward: ___

# %% [markdown]
# ---
# ## Roadmap for Milestone 2
#
# 1. **Train/test split** — perform after all preparation is finalized
# 2. **Model selection** — try Linear Regression, Random Forest, Gradient Boosting
# 3. **Hyperparameter tuning** — GridSearchCV / RandomizedSearchCV
# 4. **Evaluation** — compare models on test set using RMSE, R²
# 5. **Final presentation preparation**
